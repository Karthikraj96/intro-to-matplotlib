# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4]);

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# %%
plt.plot(x,y);

# %% [markdown]
# ## first way craeting plots

# %%
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %% [markdown]
# ## second way

# %%
fig = plt.figure()
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y)
plt.show()

# %%
# Easier and more robust going forward 
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
fig, ax = plt.subplots()
ax.plot(x, y);
fig.savefig("simple.png")

# %%
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %%
# A matplotlib workflow

# 0. Import and get matplotlib ready
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10,10))

# 3. Plot data
ax.plot(x, y)

# 4. Customize plot
ax.set(title="Sample Simple Plot", xlabel="x-axis", ylabel="y-axis")

# 5. Save & show
fig.savefig("simple-plot.png")

# %% [markdown]
# ## Line
# # Line is the default type of visualization in Matplotlib. Usually, unless specified otherwise, our plots will start out as lines.

# %%
# Create an array
x = np.linspace(0, 10, 100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# The default plot is line
fig, ax = plt.subplots()
ax.plot(x, x**2)
plt.show()

# %%
# Need to recreate our figure and axis instances when we want a new figure
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %% [markdown]
# ## Bar
# Vertical
# Horizontal

# %%
# You can make plots from a dictionary
nut_butter_prices = {"Almond butter": 10,
                     "Peanut butter": 8,
                     "Cashew butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="king's Nut Butter Store", ylabel="Price ($)")
plt.show()

# %%
## Horizontal projection
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));
ax.set(title="king's Nut Butter Store", xlabel="Price ($)")
# Out:
# [Text(0.5, 0, 'Price ($)'), Text(0.5, 1.0, "king's Nut Butter Store")]

# %%
# Make some data from a normal distribution
x = np.random.randn(1000) # pulls data from a normal distribution

fig, ax = plt.subplots()
ax.hist(x);

# %%
x = np.random.random(1000) # random data from random distribution

fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Suplots()

# %%
# Option 1: Create multiple subplots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, 
                                             ncols=2, 
                                             figsize=(10, 5))
# Plot data to each axis
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
# Option 2: Create multiple subplots
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

# Index to plot data
ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting data directly with pandas

# %%
car_sales = pd.read_csv("car-sales.csv.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2020', periods=1000))
ts
# Out:
# 2020-01-01   -0.243411
# 2020-01-02    0.913133
# 2020-01-03    0.813104
# 2020-01-04    0.933746
# 2020-01-05   -0.683812
#                 ...
# 2022-09-22    2.501591
# 2022-09-23    0.023074
# 2022-09-24   -0.429772
# 2022-09-25    1.566605
# 2022-09-26    2.246276
# Freq: D, Length: 1000, dtype: float64

# %%
ts.cumsum()
# Out:
# 2020-01-01    -0.243411
# 2020-01-02     0.669722
# 2020-01-03     1.482826
# 2020-01-04     2.416572
# 2020-01-05     1.732760
#                 ...
# 2022-09-22    10.923764
# 2022-09-23    10.946838
# 2022-09-24    10.517066
# 2022-09-25    12.083671
# 2022-09-26    14.329947
# Freq: D, Length: 1000, dtype: float64

# %%
ts.cumsum().plot();

# %%
## remove the $ symbol in price column
car_sales = pd.read_csv("car-sales.csv.csv")
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
# Add a date column
car_sales["Sale Date"] = pd.date_range("1/1/2020", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
# Make total sales column
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x='Sale Date', y='Total Sales');

# %%
# Scatter Plot
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %% [markdown]
# ### Bar
# * Concept
# * DataFrame

# %%
x = np.random.rand(10, 4)
x
# Out:
# array([[0.09255097, 0.41999211, 0.97368636, 0.55969748],
#        [0.83508526, 0.20911609, 0.0583597 , 0.96442091],
#        [0.01003969, 0.75595061, 0.55111985, 0.45993142],
#        [0.24775468, 0.62735381, 0.71025168, 0.88912723],
#        [0.98931967, 0.30950267, 0.67034437, 0.25952576],
#        [0.03656428, 0.23011825, 0.87065974, 0.14903408],
#        [0.1575397 , 0.37165122, 0.62855707, 0.75013401],
#        [0.72466612, 0.02870274, 0.28448065, 0.63209733],
#        [0.66866035, 0.64313837, 0.94607715, 0.35440111],
#        [0.30354837, 0.56143773, 0.49835232, 0.48670659]])

# %%
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.092551  0.419992  0.973686  0.559697
# 1  0.835085  0.209116  0.058360  0.964421
# 2  0.010040  0.755951  0.551120  0.459931
# 3  0.247755  0.627354  0.710252  0.889127
# 4  0.989320  0.309503  0.670344  0.259526
# 5  0.036564  0.230118  0.870660  0.149034
# 6  0.157540  0.371651  0.628557  0.750134
# 7  0.724666  0.028703  0.284481  0.632097
# 8  0.668660  0.643138  0.946077  0.354401
# 9  0.303548  0.561438  0.498352  0.486707

# %%
# First method
df.plot.bar();

# %%
# second methond
df.plot(kind="bar");

# %%
car_sales.plot(x='Make', y='Odometer (KM)', kind='bar');

# %%
car_sales.plot.bar(x='Make', y='Odometer (KM)');

# %%
#histogram
# method1
car_sales["Odometer (KM)"].plot.hist();

# %%
#method 2
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
# Default number of bins is 10 
car_sales["Odometer (KM)"].plot.hist(bins=20);

# %%
car_sales["Price"].plot.hist(bins=10);

# %%
# Let's try with another dataset
heart_disease = pd.read_csv("heart-disease.csv.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot.hist(bins=50);

# %% [markdown]
# ### Subplots
# * Concept
# * DataFrame

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Without figure size it will look like cramped 

heart_disease.plot.hist(figsize=(10, 30), subplots=True);

# %%
heart_disease.plot(figsize=(10,30),subplots=True);

# %% [markdown]
# ## Plotting with pandas using the OO method
#
# For more complicated plots, we will have to use the OO method.

# %%
# Perform data analysis on patients over 50
over_50 = heart_disease[heart_disease["age"] > 50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# 4        2   0     2       1
# 5        1   0     1       1
# 6        1   0     2       1
# ..     ...  ..   ...     ...
# 297      1   2     1       0
# 298      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [208 rows x 14 columns]

# %%
## Pyplot method
over_50.plot(kind='scatter', 
             x='age', 
             y='chol', 
             c='target', 
             figsize=(10, 6));

# %%
## OO method
fig, ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind='scatter', 
             x="age", 
             y="chol", 
             c='target', 
             ax=ax);
#ax.set_xlim([45, 100]);

# %%
# Make a bit more of a complicated plot

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"])

# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");
ax.legend(*scatter.legend_elements(), title="Target");

# %%
# What if we wanted a horizontal line going across with the mean of heart_disease["chol"]?


fig, ax = plt.subplots(figsize=(10, 6))
scatter = ax.scatter(over_50["age"], over_50["chol"], c=over_50["target"])
ax.set(title="Heart Disease and Cholesterol Levels", xlabel="Age", ylabel="Cholesterol");
ax.legend(*scatter.legend_elements(), title="Target")

# Add a meanline
ax.axhline(over_50["chol"].mean(),linestyle="--");

# %%
# Setup plot (2 rows, 1 column)
fig, (ax0, ax1) = plt.subplots(nrows=2, # 2 rows
                               ncols=1, 
                               sharex=True, 
                               figsize=(10, 8))

# Add data for ax0
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"])
# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")
ax0.legend(*scatter.legend_elements(), title="Target")

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color='b', 
            linestyle='--', 
            label="Average")


# Add data for ax1
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"])

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")
ax1.legend(*scatter.legend_elements(), title="Target")

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color='b', 
            linestyle='--', 
            label="Average")

# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');
